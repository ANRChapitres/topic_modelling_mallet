# %%
import os
import itertools
import numpy as np
import operator
import math
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt

# %%
def grouper(n, iterable, fillvalue=None):
    args = [iter(iterable)] * n
    return itertools.zip_longest(*args, fillvalue=fillvalue)

# %%
doctopic_triples = []
mallet_docnames = []

# %%
#here you can put the strings you want to get rid off when showing the titles
list_authors_to_replace=['Zola-Emile','Dumas-Alexandre-Pere','Dumas-Alexandre','Balzac-Honore-de','Verne-Jules','Sand-George','Flaubert-Gustave']
list_authors_to_find=['Zola-Emile','Balzac-Honore-de']

# %%
def replace_all(text, dic):
    for i in dic:
        text = text.replace(i, "")
    return text

# %%
with open("/home/odysseus/Bureau/ANR/code/topic_modelling_mallet/doc-topics-dumas.txt") as f:
    f.readline()  # read one line in order to skip the header
    for line in f:
        docnum, docname, *values = line.rstrip().split('\t')
        docname = os.path.basename(docname)
        if docname.split('_')[1] in list_authors_to_replace:
            docname=replace_all(docname, list_authors_to_replace)
            mallet_docnames.append(docname[6:-4])
            print(docname[6:-4])
            for topic, share in grouper(2, values):
                triple = (docname[6:-4], int(topic), float(share))
                doctopic_triples.append(triple)
# Out:
# Nana
# Le-Sphinx-des-Glaces
# Le-Phare-du-Bout-du-Monde
# L-invasion-de-la-mer
# Maitre-du-Monde
# La-tentation-de-saint-Antoine
# La-San-Felice
# Une-page-d-amour
# Vingt-ans-apres
# La-Tulipe-noire
# La-femme-au-collier-de-velours
# La-fille-du-marquis-II
# Les-Trois-Contes
# Les-maitres-sonneurs
# Laura
# La-fortune-des-Rougon
# La-faute-de-l-abbe-Mouret
# Nord-contre-Sud
# Le-Chateau-des-Carpathes
# Deux-ans-de-vacances
# Le-docteur-mysterieux-II
# Une-tenebreuse-affaireFC
# Mathias-Sandorf
# Nanon
# Madame-Bovary
# Michel-Strogoff
# Elle-et-Lui
# Les-Indes-noires
# Les-Blancs-et-les-Bleus
# Contes-d-une-grand-mere
# Illusions-perdues
# Les-dames-vertes
# Une-tenebreuse-affaire
# Germinal
# sultanetta
# Jane
# L-Education-sentimentale
# Cinq-Semaines-en-ballon
# L-assomoir
# Le-tour-du-monde-en-quatre-vingt-jours
# La-comtesse-de-Charny
# Le-Comte-de-Monte-Cristo
# La-curee
# Pot-Bouille
# Splendeurs-et-miseres-des-courtisanesFC
# La-Mare-au-Diable
# Marianne
# Promenades-autour-d-un-village
# Les-Parents-pauvres-Le-Cousin-PonsFC
# Melchior
# Vingt-mille-lieues-sous-les-mers
# Le-chateau-des-Desertes
# Le-meunier-d-Angibault
# François-le-champi
# La-petite-Fadette
# Consuelo
# Black
# Le-page-du-duc-de-Savoie-I
# De-la-Terre-a-la-Lune
# La-dame-aux-camelias
# Bouvard-et-Pecuchet
# L-Ile-Mysterieuse
# La-Reine-Margot
# Les-Trois-Mousquetaires
# Au-bonheur-des-dames
# Les-Parents-pauvres-La-Cousine-BetteFC
# Les-Louves-de-Machecoul
# Salammbo
# Le-Vicomte-de-Bragelonne

# %%
print(doctopic_triples)
# Out:
# [('Nana', 10, 0.29480427312117136), ('Nana', 16, 0.22745779172269534), ('Nana', 9, 0.10763110712684895), ('Nana', 14, 0.0868257881368594), ('Nana', 19, 0.06534812490661886), ('Nana', 18, 0.06448901837740924), ('Nana', 17, 0.05795233826385776), ('Nana', 7, 0.028555953981772), ('Nana', 11, 0.01873225758254893), ('Nana', 12, 0.01551994621246078), ('Nana', 1, 0.0127558643358733), ('Nana', 3, 0.005733602271029434), ('Nana', 6, 0.004650380995069476), ('Nana', 8, 0.0043889137905274165), ('Nana', 0, 0.001512774540564769), ('Nana', 2, 0.0012513073360227102), ('Nana', 5, 0.0009524876736889288), ('Nana', 13, 0.0008777827581054834), ('Nana', 4, 0.0003922008068130883), ('Nana', 15, 0.00016808606006275212), ('Le-Sphinx-des-Glaces', 4, 0.7831782673571491), ('Le-Sphinx-des-Glaces', 11, 0.05773281839726148), ('Le-Sphinx-des-Glaces', 12, 0.04153866409198631), ('Le-Sphinx-des-Glaces', 5, 0.03302466426753269), ('Le-Sphinx-des-Glaces', 16, 0.02885543754937242), ('Le-Sphinx-des-Glaces', 3, 0.01367067497586237), ('Le-Sphinx-des-Glaces', 18, 0.012441850258930923), ('Le-Sphinx-des-Glaces', 14, 0.009238128675502501), ('Le-Sphinx-des-Glaces', 2, 0.006078293689107347), ('Le-Sphinx-des-Glaces', 0, 0.005683314315807952), ('Le-Sphinx-des-Glaces', 13, 0.0015579741946809445), ('Le-Sphinx-des-Glaces', 1, 0.0015140875976476784), ('Le-Sphinx-des-Glaces', 15, 0.001119108224348284), ('Le-Sphinx-des-Glaces', 19, 0.0008119020451154218), ('Le-Sphinx-des-Glaces', 7, 0.0007680154480821557), ('Le-Sphinx-des-Glaces', 9, 0.0007241288510488897), ('Le-Sphinx-des-Glaces', 8, 0.0006363556569823576), ('Le-Sphinx-des-Glaces', 17, 0.0005485824629158255), ('Le-Sphinx-des-Glaces', 6, 0.0004608092688492934), ('Le-Sphinx-des-Glaces', 10, 0.00041692267181602736), ('Le-Phare-du-Bout-du-Monde', 4, 0.8774720971215978), ('Le-Phare-du-Bout-du-Monde', 12, 0.05428823183865283), ('Le-Phare-du-Bout-du-Monde', 16, 0.015909535931074994), ('Le-Phare-du-Bout-du-Monde', 0, 0.015126297239083611), ('Le-Phare-du-Bout-du-Monde', 11, 0.014049344037595458), ('Le-Phare-du-Bout-du-Monde', 3, 0.004258860387703152), ('Le-Phare-du-Bout-du-Monde', 5, 0.00416095555120423), ('Le-Phare-du-Bout-du-Monde', 14, 0.0022028588212257686), ('Le-Phare-du-Bout-du-Monde', 2, 0.0016154298022322303), ('Le-Phare-du-Bout-du-Monde', 10, 0.0015175249657333073), ('Le-Phare-du-Bout-du-Monde', 8, 0.0015175249657333073), ('Le-Phare-du-Bout-du-Monde', 18, 0.0014196201292343842), ('Le-Phare-du-Bout-du-Monde', 17, 0.001321715292735461), ('Le-Phare-du-Bout-du-Monde', 1, 0.001321715292735461), ('Le-Phare-du-Bout-du-Monde', 6, 0.000930095946739769), ('Le-Phare-du-Bout-du-Monde', 9, 0.0007342862737419228), ('Le-Phare-du-Bout-du-Monde', 15, 0.0006363814372429998), ('Le-Phare-du-Bout-du-Monde', 7, 0.0006363814372429998), ('Le-Phare-du-Bout-du-Monde', 19, 0.0004405717642451537), ('Le-Phare-du-Bout-du-Monde', 13, 0.0004405717642451537), ('L-invasion-de-la-mer', 4, 0.6011409060626249), ('L-invasion-de-la-mer', 2, 0.15169053964023985), ('L-invasion-de-la-mer', 8, 0.08248667554963358), ('L-invasion-de-la-mer', 11, 0.04792638241172552), ('L-invasion-de-la-mer', 12, 0.04634410393071286), ('L-invasion-de-la-mer', 5, 0.023276149233844103), ('L-invasion-de-la-mer', 19, 0.00903564290473018), ('L-invasion-de-la-mer', 7, 0.007286808794137242), ('L-invasion-de-la-mer', 3, 0.0051215856095936044), ('L-invasion-de-la-mer', 0, 0.0049550299800133245), ('L-invasion-de-la-mer', 14, 0.003705862758161226), ('L-invasion-de-la-mer', 15, 0.0029563624250499667), ('L-invasion-de-la-mer', 10, 0.0028730846102598268), ('L-invasion-de-la-mer', 16, 0.0022901399067288475), ('L-invasion-de-la-mer', 1, 0.0022901399067288475), ('L-invasion-de-la-mer', 18, 0.0021235842771485675), ('L-invasion-de-la-mer', 17, 0.0019570286475682876), ('L-invasion-de-la-mer', 6, 0.0010409726848767489), ('L-invasion-de-la-mer', 13, 0.0009576948700866089), ('L-invasion-de-la-mer', 9, 0.0005413057961359094), ('Maitre-du-Monde', 4, 0.6114586591596288), ('Maitre-du-Monde', 12, 0.0930559899906162), ('Mai ...

# %%
mallet_docnames = sorted(mallet_docnames)

# %%
num_docs = len(mallet_docnames)

# %%
doctopic_triples = sorted(doctopic_triples, key=operator.itemgetter(0,1))

# %%
num_topics = len(doctopic_triples) // len(mallet_docnames)
print(len(doctopic_triples))
print(num_topics)
# Out:
# 1380
# 20

# %%
doctopic = np.zeros((num_docs, num_topics))

# %%
for triple in doctopic_triples:
    docname, topic, share = triple
    row_num = mallet_docnames.index(docname)
    doctopic[row_num, topic] = share

# %%
novel_names = []

# %%
for fn in mallet_docnames:
    basename = os.path.basename(fn)
    name, ext = os.path.splitext(basename)
    name = name.rstrip('0123456789')
    novel_names.append(name)
print(len(novel_names))
# Out:
# 69

# %%
novel_names = np.asarray(novel_names)

# %%
doctopic
# Out:
# array([[ 0.00936463,  0.0025232 ,  0.00265867, ...,  0.04296214,
#          0.05102283,  0.06419766],
#        [ 0.00700333,  0.2624959 ,  0.01473275, ...,  0.00400525,
#          0.06054715,  0.12561484],
#        [ 0.01829588,  0.01467346,  0.01351848, ...,  0.00469866,
#          0.01110353,  0.06386497],
#        ...,
#        [ 0.00322013,  0.58783392,  0.0026403 , ...,  0.00148064,
#          0.00251605,  0.14250362],
#        [ 0.00161194,  0.00347315,  0.02537557, ...,  0.00227666,
#          0.00403815,  0.01879487],
#        [ 0.00246504,  0.02017306,  0.26074052, ...,  0.0014589 ,
#          0.13608009,  0.00065399]])

# %%
doctopic_orig = doctopic.copy()

# %%
num_groups = len(set(novel_names))
print(num_groups)
# Out:
# 69

# %%
doctopic_grouped = np.zeros((num_groups, num_topics))

# %%
for i, name in enumerate(sorted(set(novel_names))):
    doctopic_grouped[i, :] = np.mean(doctopic[novel_names == name, :], axis=0)

# %%
doctopic = doctopic_grouped

# %%
doctopic
# Out:
# array([[ 0.00936463,  0.0025232 ,  0.00265867, ...,  0.04296214,
#          0.05102283,  0.06419766],
#        [ 0.00700333,  0.2624959 ,  0.01473275, ...,  0.00400525,
#          0.06054715,  0.12561484],
#        [ 0.01829588,  0.01467346,  0.01351848, ...,  0.00469866,
#          0.01110353,  0.06386497],
#        ...,
#        [ 0.00322013,  0.58783392,  0.0026403 , ...,  0.00148064,
#          0.00251605,  0.14250362],
#        [ 0.00161194,  0.00347315,  0.02537557, ...,  0.00227666,
#          0.00403815,  0.01879487],
#        [ 0.00246504,  0.02017306,  0.26074052, ...,  0.0014589 ,
#          0.13608009,  0.00065399]])

# %%
N, K = doctopic.shape
print(K)
# Out:
# 20

# %%
ind = np.arange(N)

# %%
width = 0.5

# %%
plt.rcParams["figure.figsize"] = [16,9]

# %%
plt.bar(ind, doctopic[:,0], width=width)
# Out:
# <Container object of 69 artists>

# %%
plt.xticks(rotation=90)
plt.xticks(ind + width/2, novel_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7f07c47deef0>,
#   <matplotlib.axis.XTick at 0x7f07c602f9e8>,
#   <matplotlib.axis.XTick at 0x7f07c479f668>,
#   <matplotlib.axis.XTick at 0x7f07c4792518>,
#   <matplotlib.axis.XTick at 0x7f07c4792b70>,
#   <matplotlib.axis.XTick at 0x7f07c4797240>,
#   <matplotlib.axis.XTick at 0x7f07c47978d0>,
#   <matplotlib.axis.XTick at 0x7f07c4797f60>,
#   <matplotlib.axis.XTick at 0x7f07c479a5c0>,
#   <matplotlib.axis.XTick at 0x7f07c479ac50>,
#   <matplotlib.axis.XTick at 0x7f07c479f550>,
#   <matplotlib.axis.XTick at 0x7f07c4784eb8>,
#   <matplotlib.axis.XTick at 0x7f07c47974a8>,
#   <matplotlib.axis.XTick at 0x7f07c4792c88>,
#   <matplotlib.axis.XTick at 0x7f07c47eadd8>,
#   <matplotlib.axis.XTick at 0x7f07c471d748>,
#   <matplotlib.axis.XTick at 0x7f07c471ddd8>,
#   <matplotlib.axis.XTick at 0x7f07c47274a8>,
#   <matplotlib.axis.XTick at 0x7f07c4727b38>,
#   <matplotlib.axis.XTick at 0x7f07c472a208>,
#   <matplotlib.axis.XTick at 0x7f07c472a898>,
#   <matplotlib.axis.XTick at 0x7f07c472af28>,
#   <matplotlib.axis.XTick at 0x7f07c472e5f8>,
#   <matplotlib.axis.XTick at 0x7f07c472ec88>,
#   <matplotlib.axis.XTick at 0x7f07c4732358>,
#   <matplotlib.axis.XTick at 0x7f07c47329e8>,
#   <matplotlib.axis.XTick at 0x7f07c47360b8>,
#   <matplotlib.axis.XTick at 0x7f07c4736748>,
#   <matplotlib.axis.XTick at 0x7f07c4736dd8>,
#   <matplotlib.axis.XTick at 0x7f07c47394a8>,
#   <matplotlib.axis.XTick at 0x7f07c4739b38>,
#   <matplotlib.axis.XTick at 0x7f07c473d208>,
#   <matplotlib.axis.XTick at 0x7f07c473d898>,
#   <matplotlib.axis.XTick at 0x7f07c473df28>,
#   <matplotlib.axis.XTick at 0x7f07c47425f8>,
#   <matplotlib.axis.XTick at 0x7f07c4742c88>,
#   <matplotlib.axis.XTick at 0x7f07c4746358>,
#   <matplotlib.axis.XTick at 0x7f07c47469e8>,
#   <matplotlib.axis.XTick at 0x7f07c474a0b8>,
#   <matplotlib.axis.XTick at 0x7f07c474a748>,
#   <matplotlib.axis.XTick at 0x7f07c474add8>,
#   <matplotlib.axis.XTick at 0x7f07c474e4a8>,
#   <matplotlib.axis.XTick at 0x7f07c474eb38>,
#   <matplotlib.axis.XTick at 0x7f07c4752208>,
#   <matplotlib.axis.XTick at 0x7f07c4752898>,
#   <matplotlib.axis.XTick at 0x7f07c4752f28>,
#   <matplotlib.axis.XTick at 0x7f07c47565f8>,
#   <matplotlib.axis.XTick at 0x7f07c4756c50>,
#   <matplotlib.axis.XTick at 0x7f07c475a1d0>,
#   <matplotlib.axis.XTick at 0x7f07c475a860>,
#   <matplotlib.axis.XTick at 0x7f07c475aef0>,
#   <matplotlib.axis.XTick at 0x7f07c46dd5c0>,
#   <matplotlib.axis.XTick at 0x7f07c46ddc50>,
#   <matplotlib.axis.XTick at 0x7f07c46e1320>,
#   <matplotlib.axis.XTick at 0x7f07c46e19b0>,
#   <matplotlib.axis.XTick at 0x7f07c46e5080>,
#   <matplotlib.axis.XTick at 0x7f07c46e5710>,
#   <matplotlib.axis.XTick at 0x7f07c46e5da0>,
#   <matplotlib.axis.XTick at 0x7f07c46eb470>,
#   <matplotlib.axis.XTick at 0x7f07c46ebb00>,
#   <matplotlib.axis.XTick at 0x7f07c46ee1d0>,
#   <matplotlib.axis.XTick at 0x7f07c46ee860>,
#   <matplotlib.axis.XTick at 0x7f07c46eeef0>,
#   <matplotlib.axis.XTick at 0x7f07c46f35c0>,
#   <matplotlib.axis.XTick at 0x7f07c46f3c50>,
#   <matplotlib.axis.XTick at 0x7f07c46f6320>,
#   <matplotlib.axis.XTick at 0x7f07c46f69b0>,
#   <matplotlib.axis.XTick at 0x7f07c46f9080>,
#   <matplotlib.axis.XTick at 0x7f07c46f9710>],
#  <a list of 69 Text xticklabel objects>)

# %%
plt.title('Share of Topic #0')
# Out:
# Text(0.5,1,'Share of Topic #0')

# %%
plt.show()

# %%
plots = []

# %%
height_cumulative = np.zeros(N)

# %%
for k in range(K):
    color = plt.cm.coolwarm(k/K, 1)
    if k == 0:
        p = plt.bar(ind, doctopic[:, k], width, color=color)
    else:
        p = plt.bar(ind, doctopic[:, k], width, bottom=height_cumulative, color=color)
    height_cumulative += doctopic[:, k]
    plots.append(p)

# %%
plt.ylim((0, 1))
# Out:
# (0, 1)

# %%
plt.ylabel('Topics')
# Out:
# Text(0,0.5,'Topics')

# %%
plt.title('Topics in novels')
# Out:
# Text(0.5,1,'Topics in novels')

# %%
list_topics =['crime/justice', 'noblesse/titre', 'animal', 'temps', 'marine', 'mort/finitude', 'argot/camaraderie', 'famille', 'armée', 'seigneurie','affaires/mondanités','sentiment','nature','spiritualité','objet commun','modernité/technique','corps','?','plaisir/bonheur','?']

# %%
plt.xticks(rotation=90)
plt.xticks(ind+width/2, novel_names)
index=1
for name in novel_names:
    print('numero '+str(index))
    print(name)
    index+=1
# Out:
# numero 1
# Au-bonheur-des-dames
# numero 2
# Black
# numero 3
# Bouvard-et-Pecuchet
# numero 4
# Cinq-Semaines-en-ballon
# numero 5
# Consuelo
# numero 6
# Contes-d-une-grand-mere
# numero 7
# De-la-Terre-a-la-Lune
# numero 8
# Deux-ans-de-vacances
# numero 9
# Elle-et-Lui
# numero 10
# François-le-champi
# numero 11
# Germinal
# numero 12
# Illusions-perdues
# numero 13
# Jane
# numero 14
# L-Education-sentimentale
# numero 15
# L-Ile-Mysterieuse
# numero 16
# L-assomoir
# numero 17
# L-invasion-de-la-mer
# numero 18
# La-Mare-au-Diable
# numero 19
# La-Reine-Margot
# numero 20
# La-San-Felice
# numero 21
# La-Tulipe-noire
# numero 22
# La-comtesse-de-Charny
# numero 23
# La-curee
# numero 24
# La-dame-aux-camelias
# numero 25
# La-faute-de-l-abbe-Mouret
# numero 26
# La-femme-au-collier-de-velours
# numero 27
# La-fille-du-marquis-II
# numero 28
# La-fortune-des-Rougon
# numero 29
# La-petite-Fadette
# numero 30
# La-tentation-de-saint-Antoine
# numero 31
# Laura
# numero 32
# Le-Chateau-des-Carpathes
# numero 33
# Le-Comte-de-Monte-Cristo
# numero 34
# Le-Phare-du-Bout-du-Monde
# numero 35
# Le-Sphinx-des-Glaces
# numero 36
# Le-Vicomte-de-Bragelonne
# numero 37
# Le-chateau-des-Desertes
# numero 38
# Le-docteur-mysterieux-II
# numero 39
# Le-meunier-d-Angibault
# numero 40
# Le-page-du-duc-de-Savoie-I
# numero 41
# Le-tour-du-monde-en-quatre-vingt-jours
# numero 42
# Les-Blancs-et-les-Bleus
# numero 43
# Les-Indes-noires
# numero 44
# Les-Louves-de-Machecoul
# numero 45
# Les-Parents-pauvres-La-Cousine-BetteFC
# numero 46
# Les-Parents-pauvres-Le-Cousin-PonsFC
# numero 47
# Les-Trois-Contes
# numero 48
# Les-Trois-Mousquetaires
# numero 49
# Les-dames-vertes
# numero 50
# Les-maitres-sonneurs
# numero 51
# Madame-Bovary
# numero 52
# Maitre-du-Monde
# numero 53
# Marianne
# numero 54
# Mathias-Sandorf
# numero 55
# Melchior
# numero 56
# Michel-Strogoff
# numero 57
# Nana
# numero 58
# Nanon
# numero 59
# Nord-contre-Sud
# numero 60
# Pot-Bouille
# numero 61
# Promenades-autour-d-un-village
# numero 62
# Salammbo
# numero 63
# Splendeurs-et-miseres-des-courtisanesFC
# numero 64
# Une-page-d-amour
# numero 65
# Une-tenebreuse-affaire
# numero 66
# Une-tenebreuse-affaireFC
# numero 67
# Vingt-ans-apres
# numero 68
# Vingt-mille-lieues-sous-les-mers
# numero 69
# sultanetta

# %%
plt.yticks(np.arange(0, 1, 10))
# Out:
# ([<matplotlib.axis.YTick at 0x7f07c46eb0b8>],
#  <a list of 1 Text yticklabel objects>)

# %%
#Pour cette expérience, topic 0 : aventure ; topic 1 : argent ; topic 2 : mort
topic_labels = [k for k in list_topics]

# %%
plt.legend([p[0] for p in plots], topic_labels)

# %%
plt.show()
